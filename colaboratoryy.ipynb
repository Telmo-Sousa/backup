# %%
print('Welcome')
# Out:
# Welcome

# %%
print('*---------------------------*')
print('|                           |')
print('*---------------------------*')
# Out:
# *---------------------------*
# |                           |
# *---------------------------*

# %%
print('*---------------------------*')
print('|                           |')
print('*-----------|---|-----------*')
print('            |   |            ')
print('*-----------|---|-----------*')
print('|                           |')
print('*---------------------------*')
# Out:
# *---------------------------*
# |                           |
# *-----------|---|-----------*
#             |   |
# *-----------|---|-----------*
# |                           |
# *---------------------------*

# %%
from math import *

# %%
1.0 + sqrt(2) - 3 ** 2 / 2 + sin(1.7)
# Out:
# -1.0941216271744365

# %%
1.5 + 2.3 * 0.7 ** 4 % 5 + cos(2.9) // 6.9
# Out:
# 1.0522299999999998

# %%
name = input('Como te chamas? ')
print('Olá', name, 'Bem vindo!')
# Out:
# Como te chamas? X
# Olá X Bem vindo!

# %%
name = input('Qual é o teu primeiro nome? ')
surname = input('Qual é o teu apelido? ')
print('BILHETE PARA O VOO AIR42021')
print(surname,',', name)
# Out:
# Qual é o teu primeiro nome? Telmo
# Qual é o teu apelido? Sousa
# BILHETE PARA O VOO AIR42021
# Sousa , Telmo
